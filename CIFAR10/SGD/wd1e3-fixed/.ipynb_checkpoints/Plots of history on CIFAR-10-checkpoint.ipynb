# %%
import pickle
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
def plot(history, sharey=False):
    n = len(history.history['acc']) + 1
    fig, ax = plt.subplots(ncols=2, figsize=(10, 4), sharey=sharey)

    ax[0].set_ylabel('Accuracy');
    ax[0].set_xlabel('Epochs');
    lines = ax[0].plot(range(1, n, 5), history.history['acc'][::5], 'r-',
                       range(1, n, 5), history.history['val_acc'][::5], 'g-');
    ax[0].legend(lines, ('Training', 'Validation'));

    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Loss')
    lines = ax[1].plot(range(1, n, 5), history.history['loss'][::5], 'r-',
                       range(1, n, 5), history.history['val_loss'][::5], 'g-');
    ax[1].legend(lines, ('Training', 'Validation'))

    fig.tight_layout()

# %% [markdown]
# ## `1e3-real.pkl`

# %%
with open('history-1e3-real.pkl', 'rb') as f:
    history = pickle.load(f)
plot(history)

# %% [markdown]
# ## Combined

# %%
with open('history300-500.pkl', 'rb') as f:
    history2 = pickle.load(f)

with open('history500-600.pkl', 'rb') as f:
    history3 = pickle.load(f)

# %%
combined_dict = {key: history.history[key] + history2.history[key] for key in history.history}

# %%
combined_dict.keys()
# Out:
# dict_keys(['loss', 'val_loss', 'acc', 'val_acc'])

# %%
class FakeHistory:
    def __init__(self, hist):
        self.history = hist

# %%
plot(FakeHistory(combined_dict))

# %%
combined_dict = {key: history.history[key] + history2.history[key] + history3.history[key] for key in history.history}

# %%
plot(FakeHistory(combined_dict))
